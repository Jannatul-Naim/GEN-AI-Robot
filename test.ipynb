# %%
from speech import tts

# %%
r = tts.TextToSpeech()
r.speak("Hello world")
# Out:
# 🔊 Robot: Hello world

# %%
from brain import llm
llm.test()
# Out:
# [{"name": "bottle", "x_cm": -10, "z_cm": 30}, {"name": "cup", "x_cm": 10, "z_cm": 30}]
# {
#   "intent": "task",
#   "steps": [
#     {
#       "action": "pick",
#       "position": [
#         -10,
#         30
#       ]
#     },
#     {
#       "action": "pick",
#       "position": [
#         10,
#         30
#       ]
#     }
#   ],
#   "reply": "ok"
# }
# [{"name": "bottle", "x_cm": -10, "z_cm": 30}, {"name": "cup", "x_cm": 10, "z_cm": 30}]
# {
#   "intent": "task",
#   "steps": [
#     {
#       "action": "pick",
#       "position": [
#         -10,
#         30
#       ]
#     },
#     {
#       "action": "pick",
#       "position": [
#         10,
#         30
#       ]
#     }
#   ],
#   "reply": "Done"
# }
